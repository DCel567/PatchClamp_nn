# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import RobustScaler

# %%
def plot_signal_and_channels(signal, chans, zero=0, delta=5000):
    plt.figure(figsize=(20, 5))

    plt.subplot(2, 1, 1)
    plt.plot(signal[zero:zero+delta], label='Original Signal', color='blue')
    plt.title('Original Signal')
    plt.legend()

    plt.subplot(2, 1, 2) #data.index
    plt.plot(chans[zero:zero+delta], label='Channels', color='orange')
    plt.title('Channels')
    plt.legend()

# %%
def create_sequences(data, targets, seq_length=3000, step=100):
    sequences = []
    target_sequences = []
    for i in range(0, len(data) - seq_length + 1, step):
        sequences.append(data[i:i+seq_length])
        target_sequences.append(targets[i:i+seq_length])
    return np.array(sequences), np.array(target_sequences)

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate

def build_model(input_shape=(1000, 1)):
    inputs = Input(input_shape)
    
    # Encoder
    c1 = Conv1D(16, 3, activation='relu', padding='same')(inputs)
    p1 = MaxPooling1D(2)(c1)
    c2 = Conv1D(32, 3, activation='relu', padding='same')(p1)
    p2 = MaxPooling1D(2)(c2)
    
    # Bottleneck
    c3 = Conv1D(64, 3, activation='relu', padding='same')(p2)
    
    # Decoder
    u1 = UpSampling1D(2)(c3)
    u1 = concatenate([u1, c2])
    c4 = Conv1D(32, 3, activation='relu', padding='same')(u1)
    u2 = UpSampling1D(2)(c4)
    u2 = concatenate([u2, c1])
    c5 = Conv1D(16, 3, activation='relu', padding='same')(u2)
    
    # Output: 3 classes (0, 1, 2 channels open)
    outputs = Conv1D(3, 1, activation='softmax')(c5)
    
    model = models.Model(inputs, outputs)

    # Corrected loss function
    def peak_aware_loss(y_true, y_pred):
        # Create weights - higher for actual channel openings
        weights = tf.where(y_true[:, :, 1:] > 0, 1.0, 1.0)  # [batch, seq, 2]
        weights = tf.concat([tf.ones_like(weights[:, :, :1]), weights], axis=-1)  # [batch, seq, 3]
        
        # Calculate base loss
        loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        
        # Apply weights
        weighted_loss = loss * tf.reduce_mean(weights, axis=-1)
        return tf.reduce_mean(weighted_loss)
    
    # Custom metrics for class-specific performance
    def class_recall(class_idx):
        def recall(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            possible_positives = tf.reduce_sum(y_true_class)
            
            return true_positives / (possible_positives + tf.keras.backend.epsilon())
        recall.__name__ = f'recall_class_{class_idx}'
        return recall
    
    def class_precision(class_idx):
        def precision(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            predicted_positives = tf.reduce_sum(y_pred_class)
            
            return true_positives / (predicted_positives + tf.keras.backend.epsilon())
        precision.__name__ = f'precision_class_{class_idx}'
        return precision
    
    # Focused metrics compilation - only what you care about
    model.compile(optimizer='adam',
                loss=peak_aware_loss,
                metrics=[
                    'accuracy',
                    # Class 0 metrics (if you want them)
                    class_recall(0), class_precision(0),
                    # The important ones - class 1 and 2
                    class_recall(1), class_precision(1),
                    class_recall(2), class_precision(2),
                ])
    
    return model

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Add, Lambda
from tensorflow.keras import models
import tensorflow as tf

def build_model(input_shape=(1000, 1)):
    inputs = Input(input_shape)
    
    # Encoder
    c1 = Conv1D(16, 3, activation='relu', padding='same')(inputs)
    p1 = MaxPooling1D(2)(c1)
    c2 = Conv1D(32, 3, activation='relu', padding='same')(p1)
    p2 = MaxPooling1D(2)(c2)
    
    # Bottleneck
    c3 = Conv1D(64, 3, activation='relu', padding='same')(p2)
    
    # Decoder with summation skip connections
    # First upsampling
    u1 = UpSampling1D(2)(c3)
    # Ensure skip connection matches channels
    if c2.shape[-1] != u1.shape[-1]:
        c2 = Conv1D(u1.shape[-1], 1)(c2)  # Project to matching channels
    u1 = Add()([u1, c2])  # Sum instead of concatenate
    c4 = Conv1D(32, 3, activation='relu', padding='same')(u1)
    
    # Second upsampling
    u2 = UpSampling1D(2)(c4)
    # Ensure skip connection matches channels
    if c1.shape[-1] != u2.shape[-1]:
        c1 = Conv1D(u2.shape[-1], 1)(c1)  # Project to matching channels
    u2 = Add()([u2, c1])  # Sum instead of concatenate
    c5 = Conv1D(16, 3, activation='relu', padding='same')(u2)
    
    # Output
    outputs = Conv1D(3, 1, activation='softmax')(c5)
    
    model = models.Model(inputs, outputs)

        # Corrected loss function
    def peak_aware_loss(y_true, y_pred):
        # Create weights - higher for actual channel openings
        weights = tf.where(y_true[:, :, 1:] > 0, 1.0, 1.0)  # [batch, seq, 2]
        weights = tf.concat([tf.ones_like(weights[:, :, :1]), weights], axis=-1)  # [batch, seq, 3]
        
        # Calculate base loss
        loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        
        # Apply weights
        weighted_loss = loss * tf.reduce_mean(weights, axis=-1)
        return tf.reduce_mean(weighted_loss)
    
    # Custom metrics for class-specific performance
    def class_recall(class_idx):
        def recall(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            possible_positives = tf.reduce_sum(y_true_class)
            
            return true_positives / (possible_positives + tf.keras.backend.epsilon())
        recall.__name__ = f'recall_class_{class_idx}'
        return recall
    
    def class_precision(class_idx):
        def precision(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            predicted_positives = tf.reduce_sum(y_pred_class)
            
            return true_positives / (predicted_positives + tf.keras.backend.epsilon())
        precision.__name__ = f'precision_class_{class_idx}'
        return precision
    
    # Focused metrics compilation - only what you care about
    model.compile(optimizer='adam',
                loss=peak_aware_loss,
                metrics=[
                    'accuracy',
                    # Class 0 metrics (if you want them)
                    class_recall(0), class_precision(0),
                    # The important ones - class 1 and 2
                    class_recall(1), class_precision(1),
                    class_recall(2), class_precision(2),
                ])
    
    return model

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Add, Multiply, Concatenate, Activation, Lambda
from tensorflow.keras import models
import tensorflow as tf

def attention_gate(skip_connection, gating_signal, filters):
    """Attention gate mechanism for skip connections"""
    # Linear transform for skip connection
    theta_x = Conv1D(filters, 1, strides=1, padding='same')(skip_connection)
    
    # Linear transform for gating signal
    phi_g = Conv1D(filters, 1, strides=1, padding='same')(gating_signal)
    
    # Add the transformations
    combined = Add()([theta_x, phi_g])
    combined = Activation('relu')(combined)
    
    # Attention coefficients
    attention = Conv1D(1, 1, strides=1, padding='same')(combined)
    attention = Activation('sigmoid')(attention)
    
    # Apply attention to skip connection
    attended_skip = Multiply()([skip_connection, attention])
    
    return attended_skip

def build_model(input_shape=(1000, 1)):
    inputs = Input(input_shape)
    
    # Encoder
    c1 = Conv1D(16, 3, activation='relu', padding='same')(inputs)
    p1 = MaxPooling1D(2)(c1)
    c2 = Conv1D(32, 3, activation='relu', padding='same')(p1)
    p2 = MaxPooling1D(2)(c2)
    
    # Bottleneck
    c3 = Conv1D(64, 3, activation='relu', padding='same')(p2)
    
    # Decoder with attention gates
    # First upsampling
    u1 = UpSampling1D(2)(c3)
    attended_c2 = attention_gate(c2, u1, filters=32)
    u1 = Concatenate()([u1, attended_c2])  # Now using concatenation with attention
    c4 = Conv1D(32, 3, activation='relu', padding='same')(u1)
    
    # Second upsampling
    u2 = UpSampling1D(2)(c4)
    attended_c1 = attention_gate(c1, u2, filters=16)
    u2 = Concatenate()([u2, attended_c1])  # Now using concatenation with attention
    c5 = Conv1D(16, 3, activation='relu', padding='same')(u2)
    
    # Output
    outputs = Conv1D(3, 1, activation='softmax')(c5)
    
    model = models.Model(inputs, outputs)

    def peak_aware_loss(y_true, y_pred):
        # Create weights - higher for actual channel openings
        weights = tf.where(y_true[:, :, 1:] > 0, 1.0, 1.0)  # [batch, seq, 2]
        weights = tf.concat([tf.ones_like(weights[:, :, :1]), weights], axis=-1)  # [batch, seq, 3]
        
        # Calculate base loss
        loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        
        # Apply weights
        weighted_loss = loss * tf.reduce_mean(weights, axis=-1)
        return tf.reduce_mean(weighted_loss)
    
    # Custom metrics for class-specific performance
    def class_recall(class_idx):
        def recall(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            possible_positives = tf.reduce_sum(y_true_class)
            
            return true_positives / (possible_positives + tf.keras.backend.epsilon())
        recall.__name__ = f'recall_class_{class_idx}'
        return recall
    
    def class_precision(class_idx):
        def precision(y_true, y_pred):
            y_true_class = y_true[:, :, class_idx]
            y_pred_class = tf.argmax(y_pred, axis=-1) == class_idx
            y_pred_class = tf.cast(y_pred_class, tf.float32)
            
            true_positives = tf.reduce_sum(y_true_class * y_pred_class)
            predicted_positives = tf.reduce_sum(y_pred_class)
            
            return true_positives / (predicted_positives + tf.keras.backend.epsilon())
        precision.__name__ = f'precision_class_{class_idx}'
        return precision
    
    # Focused metrics compilation - only what you care about
    model.compile(optimizer='adam',
                loss=peak_aware_loss,
                metrics=[
                    'accuracy',
                    # Class 0 metrics (if you want them)
                    class_recall(0), class_precision(0),
                    # The important ones - class 1 and 2
                    class_recall(1), class_precision(1),
                    class_recall(2), class_precision(2),
                ])
    
    return model

# %%
model = build_model()

import visualkeras
visualkeras.layered_view(model, legend=True, scale_xy=0.2).show()
# Out:
# c:\Users\egrka\AppData\Local\Programs\Python\Python311\Lib\site-packages\visualkeras\layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")

# %%
st = pd.read_csv('data_extracted/1.csv', header=None, names=["time", 'signal', "chans"])

# Calculate relative features
st['signal_diff'] = st['signal'].diff().fillna(0)
st['signal_rolling_mean'] = st['signal'].rolling(window=50, center=True).mean().bfill().ffill()
st['signal_relative'] = st['signal'] - st['signal_rolling_mean']
st['signal_zscore'] = (st['signal'] - st['signal_rolling_mean']) / st['signal'].rolling(window=50, center=True).std().bfill().ffill()

# X = st[["signal_relative", "signal_zscore"]].values
X = st[['signal']].values
y = st["chans"].values

scaler = RobustScaler()
X = scaler.fit_transform(X)

# %%
seq_len = 3000
X_seq, y_seq = create_sequences(X, y, seq_length=seq_len)

y_seq_categorical = tf.keras.utils.to_categorical(y_seq, num_classes=3)  # Assuming max 2 channels

X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq_categorical, test_size=0.2, random_state=42)

# Print shapes to verify
print(f"Training data shape: {X_train.shape}")
print(f"Training targets shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}")
print(f"Test targets shape: {y_test.shape}")
# Out:
# Training data shape: (1016, 3000, 1)
# Training targets shape: (1016, 3000, 3)
# Test data shape: (254, 3000, 1)
# Test targets shape: (254, 3000, 3)

# %%
model = build_model(input_shape=(seq_len, X_seq.shape[2]))
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 3000, 1)]            0         []
#
#  conv1d_28 (Conv1D)          (None, 3000, 16)             64        ['input_4[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 1500, 16)             0         ['conv1d_28[0][0]']
#  g1D)
#
#  conv1d_29 (Conv1D)          (None, 1500, 32)             1568      ['max_pooling1d_6[0][0]']
#
#  max_pooling1d_7 (MaxPoolin  (None, 750, 32)              0         ['conv1d_29[0][0]']
#  g1D)
#
#  conv1d_30 (Conv1D)          (None, 750, 64)              6208      ['max_pooling1d_7[0][0]']
#
#  up_sampling1d_6 (UpSamplin  (None, 1500, 64)             0         ['conv1d_30[0][0]']
#  g1D)
#
#  conv1d_31 (Conv1D)          (None, 1500, 32)             1056      ['conv1d_29[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 1500, 32)             2080      ['up_sampling1d_6[0][0]']
#
#  add_6 (Add)                 (None, 1500, 32)             0         ['conv1d_31[0][0]',
#                                                                      'conv1d_32[0][0]']
#
#  activation_4 (Activation)   (None, 1500, 32)             0         ['add_6[0][0]']
#
#  conv1d_33 (Conv1D)          (None, 1500, 1)              33        ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 1500, 1)              0         ['conv1d_33[0][0]']
#
#  multiply_2 (Multiply)       (None, 1500, 32)             0         ['conv1d_29[0][0]',
#                                                                      'activation_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 1500, 96)             0         ['up_sampling1d_6[0][0]',
#  )                                                                   'multiply_2[0][0]']
#
#  conv1d_34 (Conv1D)          (None, 1500, 32)             9248      ['concatenate_2[0][0]']
#
#  up_sampling1d_7 (UpSamplin  (None, 3000, 32)             0         ['conv1d_34[0][0]']
#  g1D)
#
#  conv1d_35 (Conv1D)          (None, 3000, 16)             272       ['conv1d_28[0][0]']
#
#  conv1d_36 (Conv1D)          (None, 3000, 16)             528       ['up_sampling1d_7[0][0]']
#
#  add_7 (Add)                 (None, 3000, 16)             0         ['conv1d_35[0][0]',
#                                                                      'conv1d_36[0][0]']
#
#  activation_6 (Activation)   (None, 3000, 16)             0         ['add_7[0][0]']
#
#  conv1d_37 (Conv1D)          (None, 3000, 1)              17        ['activation_6[0][0]']
#
#  activation_7 (Activation)   (None, 3000, 1)              0         ['conv1d_37[0][0]']
#
#  multiply_3 (Multiply)       (None, 3000, 16)             0         ['conv1d_28[0][0]',
#                                                                      'activation_7[0][0]']
#
#  concatenate_3 (Concatenate  (None, 3000, 48)             0         ['up_sampling1d_7[0][0]',
#  )                                                                   'multiply_3[0][0]']
#
#  conv1d_38 (Conv1D)          (None, 3000, 16)             2320      ['concatenate_3[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 3000, 3)              51        ['conv1d_38[0][0]']
#
# ==================================================================================================
# Total params: 23445 (91.58 KB)
# Trainable params: 23445 (91.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                   epochs=20,
                   batch_size=32,
                   validation_data=(X_test, y_test),
                   callbacks=[
                       tf.keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)
                   ])
# Out:
# Epoch 1/20
# 32/32 [==============================] - 23s 194ms/step - loss: 0.4949 - accuracy: 0.9847 - recall_class_0: 0.9929 - precision_class_0: 0.9919 - recall_class_1: 0.1342 - precision_class_1: 0.2436 - recall_class_2: 0.0000e+00 - precision_class_2: 0.0000e+00 - val_loss: 0.0421 - val_accuracy: 0.9971 - val_recall_class_0: 0.9998 - val_precision_class_0: 0.9974 - val_recall_class_1: 0.7092 - val_precision_class_1: 0.9512 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 2/20
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0217 - accuracy: 0.9979 - recall_class_0: 0.9990 - precision_class_0: 0.9991 - recall_class_1: 0.8978 - precision_class_1: 0.8831 - recall_class_2: 0.0000e+00 - precision_class_2: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 0.9991 - val_recall_class_0: 1.0000 - val_precision_class_0: 0.9992 - val_recall_class_1: 0.9044 - val_precision_class_1: 0.9879 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 3/20
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0100 - accuracy: 0.9991 - recall_class_0: 0.9996 - precision_class_0: 0.9996 - recall_class_1: 0.9567 - precision_class_1: 0.9477 - recall_class_2: 0.0000e+00 - precision_class_2: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.9991 - val_recall_class_0: 1.0000 - val_precision_class_0: 0.9992 - val_recall_class_1: 0.9086 - val_precision_class_1: 0.9898 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 4/20
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0061 - accuracy: 0.9993 - recall_class_0: 0.9997 - precision_class_0: 0.9997 - recall_class_1: 0.9665 - precision_class_1: 0.9610 - recall_class_2: 0.0000e+00 - precision_class_2: 0.0000e+00 - val_loss: 0.0031 - val_accuracy: 0.9995 - val_recall_class_0: 0.9997 - val_precision_class_0: 0.9999 - val_recall_class_1: 0.9889 - val_precision_class_1: 0.9611 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 5/20
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0025 - accuracy: 0.9995 - recall_class_0: 0.9998 - precision_class_0: 0.9998 - recall_class_1: 0.9739 - precision_class_1: 0.9676 - recall_class_2: 0.0000e+00 - precision_class_2: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.9995 - val_recall_class_0: 1.0000 - val_precision_class_0: 0.9996 - val_recall_class_1: 0.9569 - val_precision_class_1: 0.9860 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 6/20
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0015 - accuracy: 0.9995 - recall_class_0: 0.9998 - precision_class_0: 0.9997 - recall_class_1: 0.9728 - precision_class_1: 0.9710 - recall_class_2: 0.0781 - precision_class_2: 0.2188 - val_loss: 0.0014 - val_accuracy: 0.9994 - val_recall_class_0: 0.9995 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9953 - val_precision_class_1: 0.9445 - val_recall_class_2: 0.3571 - val_precision_class_2: 0.5000
# Epoch 7/20
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0013 - accuracy: 0.9995 - recall_class_0: 0.9998 - precision_class_0: 0.9997 - recall_class_1: 0.9742 - precision_class_1: 0.9695 - recall_class_2: 0.4040 - precision_class_2: 0.5938 - val_loss: 8.7130e-04 - val_accuracy: 0.9997 - val_recall_class_0: 0.9999 - val_precision_class_0: 0.9998 - val_recall_class_1: 0.9830 - val_precision_class_1: 0.9875 - val_recall_class_2: 0.1429 - val_precision_class_2: 0.5000
# Epoch 8/20
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0013 - accuracy: 0.9995 - recall_class_0: 0.9998 - precision_class_0: 0.9998 - recall_class_1: 0.9751 - precision_class_1: 0.9713 - recall_class_2: 0.2946 - precision_class_2: 0.3750 - val_loss: 0.0048 - val_accuracy: 0.9977 - val_recall_class_0: 0.9989 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.8685 - val_precision_class_1: 0.8686 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.0632
# Epoch 9/20
# 32/32 [==============================] - 6s 176ms/step - loss: 0.0018 - accuracy: 0.9993 - recall_class_0: 0.9996 - precision_class_0: 0.9997 - recall_class_1: 0.9653 - precision_class_1: 0.9584 - recall_class_2: 0.3013 - precision_class_2: 0.4102 - val_loss: 8.6117e-04 - val_accuracy: 0.9997 - val_recall_class_0: 0.9998 - val_precision_class_0: 0.9999 - val_recall_class_1: 0.9936 - val_precision_class_1: 0.9769 - val_recall_class_2: 0.3571 - val_precision_class_2: 0.5000
# Epoch 10/20
# 32/32 [==============================] - 5s 167ms/step - loss: 8.4850e-04 - accuracy: 0.9998 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9868 - precision_class_1: 0.9872 - recall_class_2: 0.4777 - precision_class_2: 0.5625 - val_loss: 6.9074e-04 - val_accuracy: 0.9998 - val_recall_class_0: 0.9998 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9963 - val_precision_class_1: 0.9807 - val_recall_class_2: 0.4643 - val_precision_class_2: 0.5000
# Epoch 11/20
# 32/32 [==============================] - 5s 171ms/step - loss: 6.9126e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9918 - precision_class_1: 0.9928 - recall_class_2: 0.4598 - precision_class_2: 0.4688 - val_loss: 5.8795e-04 - val_accuracy: 0.9999 - val_recall_class_0: 0.9999 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9965 - val_precision_class_1: 0.9930 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 12/20
# 32/32 [==============================] - 5s 171ms/step - loss: 6.3961e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9916 - precision_class_1: 0.9925 - recall_class_2: 0.5513 - precision_class_2: 0.5625 - val_loss: 5.3014e-04 - val_accuracy: 0.9999 - val_recall_class_0: 0.9999 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9977 - val_precision_class_1: 0.9942 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 13/20
# 32/32 [==============================] - 5s 169ms/step - loss: 5.7962e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 1.0000 - recall_class_1: 0.9947 - precision_class_1: 0.9926 - recall_class_2: 0.5000 - precision_class_2: 0.5312 - val_loss: 5.2888e-04 - val_accuracy: 0.9999 - val_recall_class_0: 0.9999 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9988 - val_precision_class_1: 0.9875 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 14/20
# 32/32 [==============================] - 5s 168ms/step - loss: 5.5072e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9940 - precision_class_1: 0.9934 - recall_class_2: 0.5246 - precision_class_2: 0.5312 - val_loss: 8.7575e-04 - val_accuracy: 0.9996 - val_recall_class_0: 0.9996 - val_precision_class_0: 1.0000 - val_recall_class_1: 1.0000 - val_precision_class_1: 0.9587 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 15/20
# 32/32 [==============================] - 6s 173ms/step - loss: 8.8507e-04 - accuracy: 0.9996 - recall_class_0: 0.9998 - precision_class_0: 0.9998 - recall_class_1: 0.9820 - precision_class_1: 0.9774 - recall_class_2: 0.5045 - precision_class_2: 0.5312 - val_loss: 5.1578e-04 - val_accuracy: 0.9999 - val_recall_class_0: 0.9999 - val_precision_class_0: 1.0000 - val_recall_class_1: 0.9968 - val_precision_class_1: 0.9883 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 16/20
# 32/32 [==============================] - 5s 171ms/step - loss: 5.7349e-04 - accuracy: 0.9998 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9910 - precision_class_1: 0.9896 - recall_class_2: 0.5134 - precision_class_2: 0.5312 - val_loss: 5.0382e-04 - val_accuracy: 0.9998 - val_recall_class_0: 0.9998 - val_precision_class_0: 1.0000 - val_recall_class_1: 1.0000 - val_precision_class_1: 0.9825 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 17/20
# 32/32 [==============================] - 5s 163ms/step - loss: 5.0030e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9928 - precision_class_1: 0.9926 - recall_class_2: 0.5223 - precision_class_2: 0.5312 - val_loss: 4.9088e-04 - val_accuracy: 0.9998 - val_recall_class_0: 1.0000 - val_precision_class_0: 0.9998 - val_recall_class_1: 0.9824 - val_precision_class_1: 0.9991 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 18/20
# 32/32 [==============================] - 5s 171ms/step - loss: 5.0424e-04 - accuracy: 0.9999 - recall_class_0: 0.9999 - precision_class_0: 0.9999 - recall_class_1: 0.9930 - precision_class_1: 0.9905 - recall_class_2: 0.5737 - precision_class_2: 0.5938 - val_loss: 3.9022e-04 - val_accuracy: 0.9999 - val_recall_class_0: 1.0000 - val_precision_class_0: 0.9999 - val_recall_class_1: 0.9930 - val_precision_class_1: 0.9991 - val_recall_class_2: 0.5000 - val_precision_class_2: 0.5000
# Epoch 19/20
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0013 - accuracy: 0.9996 - recall_class_0: 0.9997 - precision_class_0: 0.9998 - recall_class_1: 0.9831 - precision_class_1: 0.9763 - recall_class_2: 0.5290 - precision_class_2: 0.5570 - val_loss: 0.0057 - val_accuracy: 0.9985 - val_recall_class_0: 0.9986 - val_precision_class_0: 1.0000 - val_recall_class_1: 1.0000 - val_precision_class_1: 0.8512 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00
# Epoch 20/20
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0046 - accuracy: 0.9987 - recall_class_0: 0.9993 - precision_class_0: 0.9996 - recall_class_1: 0.9555 - precision_class_1: 0.9158 - recall_class_2: 0.0580 - precision_class_2: 0.0477 - val_loss: 0.0019 - val_accuracy: 0.9993 - val_recall_class_0: 0.9999 - val_precision_class_0: 0.9995 - val_recall_class_1: 0.9485 - val_precision_class_1: 0.9740 - val_recall_class_2: 0.0000e+00 - val_precision_class_2: 0.0000e+00

# %% [markdown]
# 33/33 [==============================] - 57s 2s/step - loss: 0.2094 - accuracy: 0.9490 - val_loss: 1.0982 - val_accuracy: 0.4959
# Epoch 2/20
# 33/33 [==============================] - 60s 2s/step - loss: 0.0277 - accuracy: 0.9948 - val_loss: 0.0918 - val_accuracy: 0.9883
# Epoch 3/20
# 33/33 [==============================] - 63s 2s/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 0.0763 - val_accuracy: 0.9934
# Epoch 4/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.0161 - accuracy: 0.9956 - val_loss: 0.1116 - val_accuracy: 0.9934
# Epoch 5/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.1260 - val_accuracy: 0.9934
# Epoch 6/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.1416 - val_accuracy: 0.9934

# %%
#thru attention:
import matplotlib.pyplot as plt

def plot_history(history):
    metrics = [m for m in history.history.keys() if not m.startswith('val_')]
    val_metrics = [f'val_{m}' for m in metrics if f'val_{m}' in history.history]

    for metric in metrics:
        plt.figure(figsize=(8, 5))
        plt.plot(history.history[metric], label=f'Train {metric}')
        if f'val_{metric}' in history.history:
            plt.plot(history.history[f'val_{metric}'], label=f'Val {metric}')
        plt.xlabel('Epoch')
        plt.ylabel(metric)
        plt.title(f'{metric} over epochs')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

plot_history(history)

# %%
#thru summing:
import matplotlib.pyplot as plt

def plot_history(history):
    metrics = [m for m in history.history.keys() if not m.startswith('val_')]
    val_metrics = [f'val_{m}' for m in metrics if f'val_{m}' in history.history]

    for metric in metrics:
        plt.figure(figsize=(8, 5))
        plt.plot(history.history[metric], label=f'Train {metric}')
        if f'val_{metric}' in history.history:
            plt.plot(history.history[f'val_{metric}'], label=f'Val {metric}')
        plt.xlabel('Epoch')
        plt.ylabel(metric)
        plt.title(f'{metric} over epochs')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

plot_history(history)

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    metrics = [m for m in history.history.keys() if not m.startswith('val_')]
    val_metrics = [f'val_{m}' for m in metrics if f'val_{m}' in history.history]

    for metric in metrics:
        plt.figure(figsize=(8, 5))
        plt.plot(history.history[metric], label=f'Train {metric}')
        if f'val_{metric}' in history.history:
            plt.plot(history.history[f'val_{metric}'], label=f'Val {metric}')
        plt.xlabel('Epoch')
        plt.ylabel(metric)
        plt.title(f'{metric} over epochs')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

plot_history(history)

# %%
# Prediction function
def predict_channels(signal_sequence, model, scaler, rolling_window=50):
    df = pd.DataFrame({'signal': signal_sequence})
    df['signal_rolling_mean'] = df['signal'].rolling(window=rolling_window, center=True).mean().bfill().ffill()
    df['signal_relative'] = df['signal'] - df['signal_rolling_mean']
    df['signal_zscore'] = (df['signal'] - df['signal_rolling_mean']) / df['signal'].rolling(window=rolling_window, center=True).std().bfill().ffill()
    
    # X_new = scaler.transform(df[["signal_relative", "signal_zscore"]].values)
    X_new = scaler.transform(df[["signal"]].values)
    X_new_seq = np.expand_dims(X_new, axis=0)
    
    preds = model.predict(X_new_seq)[0]
    channel_counts = np.argmax(preds, axis=1)
    
    return channel_counts

# %%
p = 5

probe = X_train[p]
y_probe = y_train[p]
plot_signal_and_channels(probe[:, 0], y_probe[:, 0])

# %%
def plot_signal_and_channels_and_truth(signal, chans, truth, zero=0, delta=5000):
    plt.figure(figsize=(20, 5))

    plt.subplot(3, 1, 1)
    plt.plot(signal[zero:zero+delta], label='Original Signal', color='blue')
    plt.title('Original Signal')
    plt.legend()

    plt.subplot(3, 1, 2) #data.index
    plt.plot(chans[zero:zero+delta], label='Channels', color='orange')
    plt.title('Channels')
    plt.legend()

    plt.subplot(3, 1, 3) #data.index
    plt.plot(truth[zero:zero+delta], label='Truth', color='green')
    plt.title('Truth')
    plt.legend()

# %%
#attention
for i in range(10):
    # Test
    test_signal = X_train[i][:, 0]
    predicted_channels = predict_channels(test_signal, model, scaler)

    plot_signal_and_channels_and_truth(test_signal, predicted_channels, y_train[i][:, 0])
    # plot_signal_and_channels(test_signal, y_train[i][:, 0])
# Out:
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
#sum
for i in range(10):
    # Test
    test_signal = X_train[i][:, 0]
    predicted_channels = predict_channels(test_signal, model, scaler)

    plot_signal_and_channels_and_truth(test_signal, predicted_channels, y_train[i][:, 0])
    # plot_signal_and_channels(test_signal, y_train[i][:, 0])
# Out:
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
# concat 
for i in range(10):
    # Test
    test_signal = X_train[i][:, 0]
    predicted_channels = predict_channels(test_signal, model, scaler)

    plot_signal_and_channels_and_truth(test_signal, predicted_channels, y_train[i][:, 0])
    # plot_signal_and_channels(test_signal, y_train[i][:, 0])
# Out:
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
